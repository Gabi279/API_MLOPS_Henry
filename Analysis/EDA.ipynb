# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
#cargo los datos delas películas y de los créditos

data_movies = pd.read_csv("../Data/movies_dataset.csv")
data_credits = pd.read_csv("../Data/credits.csv")

data_movies.columns
# Out:
# C:\Users\cgabr\AppData\Local\Temp\ipykernel_6608\1498727921.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_movies = pd.read_csv("../Data/movies_dataset.csv")
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
datos_relevantes = data_movies[['vote_count', 'vote_average']]

# Calcular la matriz de correlación
matriz_correlacion = datos_relevantes.corr()

print(matriz_correlacion)
# Out:
#               vote_count  vote_average
# vote_count      1.000000      0.123607
# vote_average    0.123607      1.000000

# %%
# Crear un mapa de calor de la matriz de correlación
plt.figure(figsize=(8, 6))
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de Correlación')
plt.show()

# %%
data_movies['title'] = data_movies['title'].dropna()

# %%
titles = str(data_movies['title'])

# %%
# Crea la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(titles)

# Muestra la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # No mostrar ejes
plt.show()
